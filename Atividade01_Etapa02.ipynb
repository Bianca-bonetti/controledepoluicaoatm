# %% [markdown]
# # Atividade 1 - Etapa 2
#
# Controle de Poluição Atmosférica\
# Professor: Leonardo Hoinaski\
# Aluna: Bianca Bonetti Nunes

# %% [markdown]
# # 1.1 Numpy arrays

# %%
import numpy as np

# Criando um vetor de dados aleatórios
data = np.random.rand(1000,2)

# Verificando o tamanho do vetor
print(data.shape)
print(np.size(data))

# Print de uma amostra dos dados
print(data[0:10]) #mostra linhas de 0 a 10
print(data[0:10].shape)
# Out:
# (1000, 2)
# 2000
# [[0.88420904 0.64133987]
#  [0.49691795 0.19822516]
#  [0.49512579 0.19154092]
#  [0.97251829 0.4193688 ]
#  [0.22220663 0.67907408]
#  [0.3810274  0.87833606]
#  [0.44070938 0.02077617]
#  [0.29497607 0.33798079]
#  [0.0101675  0.45219486]
#  [0.3635441  0.14552986]]
# (10, 2)

# %%
# Usando Monte-Carlo
dataMax = 1000
dataMin = 10
data=(dataMax - dataMin)*data + dataMin #multiplica osvalores da matriz por 1000-10 e soma 10
print(data[0:10])
# Out:
# [[885.36694757 644.92647552]
#  [501.94877352 206.24290531]
#  [500.1745288  199.62550819]
#  [972.79311186 425.17511522]
#  [229.98456754 682.28333495]
#  [387.21712478 879.55269479]
#  [446.30228379  30.56840441]
#  [302.02630837 344.600984  ]
#  [ 20.06582522 457.67291034]
#  [369.90865865 154.07455874]]

# %%
import matplotlib.pyplot as plt #comando que vai plotar dados em um gráfico

fig, ax = plt.subplots(3) #criar 3 graficos onde vai plotar os dados
ax[0].plot(data) #plotar todos os dados da matriz
ax[1].plot(data[:,0]) #plotar todos os dados da primeira coluna
ax[2].plot(data[:,1])#plotar dados da segunda coluna
print(type(data))
# Out:
# <class 'numpy.ndarray'>

# %%
# Criando um dado 2D 
data3d = np.sin(np.random.rand(1000,1000))
print(data3d)
# Out:
# [[0.83394127 0.32611945 0.72615888 ... 0.77056981 0.49282755 0.78458488]
#  [0.46674304 0.4233917  0.14582305 ... 0.38181067 0.74850023 0.79595101]
#  [0.19444198 0.40893533 0.44343077 ... 0.33091034 0.52141308 0.22126546]
#  ...
#  [0.09365111 0.09010683 0.47701704 ... 0.7442034  0.72268124 0.22246053]
#  [0.59862257 0.52915725 0.58099542 ... 0.59503266 0.36774768 0.69144195]
#  [0.63985535 0.72181216 0.0369144  ... 0.31187187 0.15015861 0.38489371]]

# %%
# Plotando um dado 3D
fig2, ax2 = plt.subplots()
ax2.pcolor(data3d)

# %%
# Criando vertor temporal
dtime = np.arange(np.datetime64("2022-01-01"), np.datetime64("2023-01-01"), np.timedelta64(1, "h"))#lista de horas entre as datas
print(dtime[1:10])
print(dtime.shape)
print(type(dtime))
# Out:
# ['2022-01-01T01' '2022-01-01T02' '2022-01-01T03' '2022-01-01T04'
#  '2022-01-01T05' '2022-01-01T06' '2022-01-01T07' '2022-01-01T08'
#  '2022-01-01T09']
# (8760,)
# <class 'numpy.ndarray'>

# %%
import pandas as pd

# Criando um dataframe
df = pd.DataFrame()

# %%
# Monstrando um dataframe
df['datetime'] = dtime

# %%
# Criando uma coluna random dentro do dataframe df
df['random'] = np.random.rand(df.shape[0])

# %%
df['random'][1:10]
# Out:
# 1    0.787193
# 2    0.625579
# 3    0.382400
# 4    0.778567
# 5    0.460613
# 6    0.514691
# 7    0.396393
# 8    0.004822
# 9    0.711229
# Name: random, dtype: float64

# %%
# Indexação
df.iloc[:,0] #seleciona todas as linhas da coluna 0
# Out:
# 0      2022-01-01 00:00:00
# 1      2022-01-01 01:00:00
# 2      2022-01-01 02:00:00
# 3      2022-01-01 03:00:00
# 4      2022-01-01 04:00:00
#                ...
# 8755   2022-12-31 19:00:00
# 8756   2022-12-31 20:00:00
# 8757   2022-12-31 21:00:00
# 8758   2022-12-31 22:00:00
# 8759   2022-12-31 23:00:00
# Name: datetime, Length: 8760, dtype: datetime64[s]

# %%
# Colocando o datetime como index
df = df.set_index(df['datetime'])
df
# Out:
#                                datetime    random
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.651187
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.787193
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.625579
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.382400
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.778567
# ...                                 ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.488520
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.685351
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.815848
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.716307
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.187665
#
# [8760 rows x 2 columns]

# %%
# Criando colunas com ano, mês e dia
df['year'] = df.index.year
df['month'] = df.index.month
df['day'] = df.index.day

# %%
tt = np.arange(0,df.shape[0],1)
print(tt.shape)
df['sazonal'] = (np.cos(tt/(360*4)))
df['timeSeries'] = 10*df['sazonal']+df['random']
#df['sazonal'].plot()
df['timeSeries'].plot(color='red')
# Out:
# (8760,)
# <Axes: xlabel='datetime'>

# %%
df
# Out:
#                                datetime    random  year  month  day   sazonal  \
# datetime
# 2022-01-01 00:00:00 2022-01-01 00:00:00  0.981223  2022      1    1  1.000000
# 2022-01-01 01:00:00 2022-01-01 01:00:00  0.528291  2022      1    1  1.000000
# 2022-01-01 02:00:00 2022-01-01 02:00:00  0.751571  2022      1    1  0.999999
# 2022-01-01 03:00:00 2022-01-01 03:00:00  0.373621  2022      1    1  0.999998
# 2022-01-01 04:00:00 2022-01-01 04:00:00  0.508970  2022      1    1  0.999996
# ...                                 ...       ...   ...    ...  ...       ...
# 2022-12-31 19:00:00 2022-12-31 19:00:00  0.330951  2022     12   31  0.979401
# 2022-12-31 20:00:00 2022-12-31 20:00:00  0.063757  2022     12   31  0.979541
# 2022-12-31 21:00:00 2022-12-31 21:00:00  0.915493  2022     12   31  0.979680
# 2022-12-31 22:00:00 2022-12-31 22:00:00  0.899750  2022     12   31  0.979819
# 2022-12-31 23:00:00 2022-12-31 23:00:00  0.838677  2022     12   31  0.979958
#
#                      timeSeries
# datetime
# 2022-01-01 00:00:00   10.981223
# 2022-01-01 01:00:00   10.528288
# 2022-01-01 02:00:00   10.751561
# 2022-01-01 03:00:00   10.373599
# 2022-01-01 04:00:00   10.508932
# ...                         ...
# 2022-12-31 19:00:00   10.124958
# 2022-12-31 20:00:00    9.859165
# 2022-12-31 21:00:00   10.712296
# 2022-12-31 22:00:00   10.697943
# 2022-12-31 23:00:00   10.638256
#
# [8760 rows x 7 columns]

# %%
# Salvar meu dataframe

df.to_csv(r'C:\Users\BiaBN\OneDrive\Documentos\controledepoluicaoatm\noise_2022.csv')

# %%
# Criando uma função
def noiseCreation(path, year):
    """Esta função cria um ruido com sazonalidade.
    Inputs:
        path = asdasdas
        year = asdasdasdas
    """
    
    # Criando um dataframe
    df = pd.DataFrame()
    
    # Criando vertor temporal
    dtime = np.arange(np.datetime64(str(year)+"-01-01"), np.datetime64(str(year+1)+"-01-01"), np.timedelta64(1, "h"))
    
    # Monstrando um dataframe
    df['datetime'] = dtime
        
    # Datetime como index do dataframe
    df = df.set_index(df['datetime'])
    
    # Criando colunas com ano, mês e dia
    df['year'] = df.index.year
    df['month'] = df.index.month
    df['day'] = df.index.day
    
    # Crio uma coluna random
    df['random'] = np.random.rand(df.shape[0])
    
    # Adicionar sazonalidade
    tt = np.arange(0,df.shape[0],1)
    print(tt.shape)
    df['sazonal'] = (np.cos(tt/(360*4)))
    df['timeSeries'] = 10*df['sazonal']+df['random']
    #df['sazonal'].plot()
    df['timeSeries'].plot(color='red')
    df.to_csv(path+'/noise_'+str(year)+'.csv')
    return df

# %%
path = 'C:/Users/BiaBN/OneDrive/Documentos/controledepoluicaoatm'
df2 = noiseCreation(path,2050)
# Out:
# (8760,)

# %%
# Primeira opção de loop
for ii in range(2002,2010): #cria um loop onde vai ser realizados os comandos abaixo sendo ii==2002 
    #em seguida os comandos se repetem com ii==2003 até chegar em 2009 quando o loop termina (sempre termina 1 numero antes)
    print(ii)
    df = noiseCreation(path,ii)
# Out:
# 2002
# (8760,)
# 2003
# (8760,)
# 2004
# (8784,)
# 2005
# (8760,)
# 2006
# (8760,)
# 2007
# (8760,)
# 2008
# (8784,)
# 2009
# (8760,)

# %%
df
# Out:
#                                datetime  year  month  day    random   sazonal  \
# datetime
# 2009-01-01 00:00:00 2009-01-01 00:00:00  2009      1    1  0.862686  1.000000
# 2009-01-01 01:00:00 2009-01-01 01:00:00  2009      1    1  0.424359  1.000000
# 2009-01-01 02:00:00 2009-01-01 02:00:00  2009      1    1  0.842281  0.999999
# 2009-01-01 03:00:00 2009-01-01 03:00:00  2009      1    1  0.038838  0.999998
# 2009-01-01 04:00:00 2009-01-01 04:00:00  2009      1    1  0.757880  0.999996
# ...                                 ...   ...    ...  ...       ...       ...
# 2009-12-31 19:00:00 2009-12-31 19:00:00  2009     12   31  0.454728  0.979401
# 2009-12-31 20:00:00 2009-12-31 20:00:00  2009     12   31  0.223360  0.979541
# 2009-12-31 21:00:00 2009-12-31 21:00:00  2009     12   31  0.400505  0.979680
# 2009-12-31 22:00:00 2009-12-31 22:00:00  2009     12   31  0.604008  0.979819
# 2009-12-31 23:00:00 2009-12-31 23:00:00  2009     12   31  0.713426  0.979958
#
#                      timeSeries
# datetime
# 2009-01-01 00:00:00   10.862686
# 2009-01-01 01:00:00   10.424357
# 2009-01-01 02:00:00   10.842272
# 2009-01-01 03:00:00   10.038816
# 2009-01-01 04:00:00   10.757841
# ...                         ...
# 2009-12-31 19:00:00   10.248736
# 2009-12-31 20:00:00   10.018767
# 2009-12-31 21:00:00   10.197308
# 2009-12-31 22:00:00   10.402201
# 2009-12-31 23:00:00   10.513005
#
# [8760 rows x 7 columns]

# %%
anos = [2001,2030,2032,2053,2060]

for ano in anos:
    print(ano)
    if ano > 2030:
        df = noiseCreation(path,ano) #cria dados apenas para os anos maiores que 2030 como podemos ver no gráfico
# Out:
# 2001
# 2030
# 2032
# (8784,)
# 2053
# (8760,)
# 2060
# (8784,)

# %%
import os
files = os.listdir(path)
print(files)

allData = []
for file in files:
    if file.endswith('.csv'):
        print(file)
        data = pd.read_csv(path+'/'+file)
        allData.append(data) #adiciona cada arquivo csv na lista AllData
# Out:
# ['.git', '.gitignore', '.ipynb_checkpoints', 'Atividade1_Etapa1.ipynb', 'Atividade1_Etapa2.ipynb', 'Aula01.ipynb', 'inputs', 'noise_2002.csv', 'noise_2003.csv', 'noise_2004.csv', 'noise_2005.csv', 'noise_2006.csv', 'noise_2007.csv', 'noise_2008.csv', 'noise_2009.csv', 'noise_2022.csv', 'noise_2032.csv', 'noise_2050.csv', 'noise_2053.csv', 'noise_2060.csv', 'README.md', 'Scripts', 'test', 'test2', 'venv']
# noise_2002.csv
# noise_2003.csv
# noise_2004.csv
# noise_2005.csv
# noise_2006.csv
# noise_2007.csv
# noise_2008.csv
# noise_2009.csv
# noise_2022.csv
# noise_2032.csv
# noise_2050.csv
# noise_2053.csv
# noise_2060.csv

# %%
allDataDf = pd.concat(allData)

# %%
allDataDf #foi adicionado a AllData todos os arquivos csv criados nessa atividade
# Out:
#                  datetime           datetime.1  year  month  day    random  \
# 0     2002-01-01 00:00:00  2002-01-01 00:00:00  2002      1    1  0.371829
# 1     2002-01-01 01:00:00  2002-01-01 01:00:00  2002      1    1  0.795714
# 2     2002-01-01 02:00:00  2002-01-01 02:00:00  2002      1    1  0.094283
# 3     2002-01-01 03:00:00  2002-01-01 03:00:00  2002      1    1  0.949275
# 4     2002-01-01 04:00:00  2002-01-01 04:00:00  2002      1    1  0.185673
# ...                   ...                  ...   ...    ...  ...       ...
# 8779  2060-12-31 19:00:00  2060-12-31 19:00:00  2060     12   31  0.088515
# 8780  2060-12-31 20:00:00  2060-12-31 20:00:00  2060     12   31  0.009082
# 8781  2060-12-31 21:00:00  2060-12-31 21:00:00  2060     12   31  0.329047
# 8782  2060-12-31 22:00:00  2060-12-31 22:00:00  2060     12   31  0.889086
# 8783  2060-12-31 23:00:00  2060-12-31 23:00:00  2060     12   31  0.170787
#
#        sazonal  timeSeries
# 0     1.000000   10.371829
# 1     1.000000   10.795712
# 2     0.999999   10.094273
# 3     0.999998   10.949253
# 4     0.999996   10.185635
# ...        ...         ...
# 8779  0.982630    9.914815
# 8780  0.982759    9.836668
# 8781  0.982887   10.157915
# 8782  0.983014   10.719231
# 8783  0.983142   10.002204
#
# [113976 rows x 8 columns]

# %%
plt.plot(allDataDf['datetime'],allDataDf['timeSeries'])
